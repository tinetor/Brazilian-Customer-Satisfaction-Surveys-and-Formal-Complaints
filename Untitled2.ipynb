# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)

# %% [markdown]
# Questions:
#     Is the survey satisfaction reliable?
#     Do the questions capture the main complaints?
#     is there a difference in the results in different states? The telephone sector is also the top rank complaint in all the states? is there a correlation between non-specialized stores and complaints?

# %% [markdown]
# **Dataset overview Sindec**

# %% [markdown]
# The first line of code returns a warning message. it could be fixed, but the explanation of the whole process it is more clear if we don't fix it right away because I had to take a few steps before identifying the problem.

# %%
date_columns=['AnoCalendario','DataArquivamento','DataAbertura'] #columns to be handle in the dataformat
sindec=pd.read_csv("C:\\Users\\tiago\\Downloads\\carros\\reclamacoes\\reclamacao fundamentdas\\CNRF2018.csv",parse_dates=date_columns)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (9,13,18,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
sindec.iloc[:,4:]
# Out:
#          Regiao  UF                                     strRazaoSocial  \
# 0      Nordeste  MA                         MOTOTEC SERVIÇOS LTDA - ME
# 1      Nordeste  MA                               MAGAZINE LILIANI S/A
# 2      Nordeste  MA                SAMSUNG ELETRÔNICA DA AMAZONIA LTDA
# 3      Nordeste  MA    TECNO INDUSTRIA E COMERCIO DE COMPUTADORES LTDA
# 4      Nordeste  MA         SUPERTECH INFORMATICA - JC & CIA LTDA - ME
# ...         ...  ..                                                ...
# 39055   Sudeste  MG                 BANCO LOSANGO S.A - BANCO MULTIPLO
# 39056   Sudeste  MG       MERCADOLIVRE.COM ATIVIDADES DE INTERNET LTDA
# 39057  Nordeste  RN                   ACBZ IMPORTACAO E COMERCIO LTDA.
# 39058  Nordeste  RN                    NET SERVIÇOS DE COMUNICAÇÃO S/A
# 39059  Nordeste  RN  CREFISA S.A. CREDITO FINANCIAMENTO E INVESTIME...
#
#                           strNomeFantasia  Tipo        NumeroCNPJ  \
# 0                                 MOTOTEC   1.0    08852225000188
# 1                                 LILIANI   1.0    11590296003775
# 2                                 SAMSUNG   1.0              None
# 3                                   IBYTE   1.0    07272825001690
# 4                   SUPERTECH INFORMATICA   1.0    09632201000186
# ...                                   ...   ...               ...
# 39055  BANCO LOSANGO S/A - BANCO MÚLTIPLO   1.0  33254319000100.0
# 39056                       MERCADO LIVRE   1.0   3361252000134.0
# 39057                      ASUS NO BRASIL   1.0   9509531000189.0
# 39058                                 NET   1.0    108786018889.0
# 39059                         CREFISA S/A   1.0              None
#
#        RadicalCNPJ                                   RazaoSocialRFB  \
# 0        8852225.0                            MOTOTEC SERVICOS LTDA
# 1       11590296.0                             MAGAZINE LILIANI S/A
# 2         280273.0              SAMSUNG ELETRONICA DA AMAZONIA LTDA
# 3        7272825.0  TECNO INDUSTRIA E COMERCIO DE COMPUTADORES LTDA
# 4        9632201.0                                    JC & CIA LTDA
# ...            ...                                              ...
# 39055   33254319.0      HSBC FINANCE (BRASIL) S.A. - BANCO MULTIPLO
# 39056    3361252.0     MERCADOLIVRE.COM ATIVIDADES DE INTERNET LTDA
# 39057    9509531.0                 ACBZ IMPORTACAO E COMERCIO LTDA.
# 39058     108786.0                  NET SERVICOS DE COMUNICACAO S/A
# 39059          NaN                                              NaN
#
#                                        NomeFantasiaRFB CNAEPrincipal  \
# 0                                              MOTOTEC       4752100
# 1                                              LILIANI       4754701
# 2                                                  NaN       2632900
# 3      TECNO INDUSTRIA E COMERCIO DE COMPUTADORES LTDA       4753900
# 4                                SUPERTECH INFORMATICA       4751201
# ...                                                ...           ...
# 39055                                              NaN     6431000.0
# 39056                                              NaN     7490104.0
# 39057                                              NaN     4651601.0
# 39058                                              NaN     8299799.0
# 39059                                              NaN             0
#
#                                        DescCNAEPrincipal Atendida  \
# 0      COMÉRCIO VAREJISTA ESPECIALIZADO DE EQUIPAMENT...        S
# 1                           COMÉRCIO VAREJISTA DE MÓVEIS        S
# 2      FABRICAÇÃO DE APARELHOS TELEFÔNICOS E DE OUTRO...        S
# 3      COMÉRCIO VAREJISTA ESPECIALIZADO DE ELETRODOMÉ...        S
# 4                                                    nan        S
# ...                                                  ...      ...
# 39055           BANCOS MÚLTIPLOS, SEM CARTEIRA COMERCIAL        S
# 39056  ATIVIDADES DE INTERMEDIAÇÃO E AGENCIAMENTO DE ...        S
# 39057  COMÉRCIO ATACADISTA DE EQUIPAMENTOS DE INFORMÁ...        N
# 39058  OUTRAS ATIVIDADES DE SERVIÇOS PRESTADOS PRINCI...        S
# 39059                                                nan        N
#
#        CodigoAssunto                                   DescricaoAssunto  \
# 0              101.0  Telefone ( Convencional, Celular, Interfone, E...
# 1              101.0  Telefone ( Convencional, Celular, Interfone, E...
# 2              101.0  Telefone ( Convencional, Celular, Interfone, E...
# 3               76.0                                   Outros Contratos
# 4               76.0                                   Outros Contratos
# ...              ...                                                ...
# 39055           54.0                                  Cartão de Crédito
# 39056          106.0  Artigo de Leitura ( Formal, Jornal, Revista, F...
# 39057          101.0  Telefone ( Convencional, Celular, Interfone, E...
# 39058          186.0  Telefonia Fixa ( Plano de Expansão / Compra e ...
# 39059           63.0                                         Financeira
#
#       CodigoProblema DescricaoProblema SexoConsumidor FaixaEtariaConsumidor  \
# 0                  0               NaN              F    entre 41 a 50 anos
# 1                  0               NaN              F    entre 41 a 50 anos
# 2                  0               NaN              F    entre 41 a 50 anos
# 3                  0               NaN              F    entre 31 a 40 anos
# 4                  0               NaN              F    entre 31 a 40 anos
# ...              ...               ...            ...                   ...
# 39055              0               NaN              F    entre 61 a 70 anos
# 39056              0               NaN              F           até 20 anos
# 39057              0               NaN              F    entre 21 a 30 anos
# 39058              0               NaN              F    entre 61 a 70 anos
# 39059              0               NaN              F    entre 61 a 70 anos
#
#       CEPConsumidor
# 0          65631110
# 1          65631110
# 2          65631110
# 3          65630020
# 4          65630020
# ...             ...
# 39055    35180144.0
# 39056    90035030.0
# 39057    59115110.0
# 39058    59073101.0
# 39059    59092390.0
#
# [39060 rows x 19 columns]

# %%
sindec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39060 entries, 0 to 39059
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AnoCalendario          39060 non-null  datetime64[ns]
#  1   DataArquivamento       39046 non-null  datetime64[ns]
#  2   DataAbertura           39059 non-null  datetime64[ns]
#  3   CodigoRegiao           39060 non-null  int64
#  4   Regiao                 39060 non-null  object
#  5   UF                     39060 non-null  object
#  6   strRazaoSocial         39058 non-null  object
#  7   strNomeFantasia        32242 non-null  object
#  8   Tipo                   39047 non-null  float64
#  9   NumeroCNPJ             37742 non-null  object
#  10  RadicalCNPJ            37622 non-null  float64
#  11  RazaoSocialRFB         34789 non-null  object
#  12  NomeFantasiaRFB        15662 non-null  object
#  13  CNAEPrincipal          34789 non-null  object
#  14  DescCNAEPrincipal      34600 non-null  object
#  15  Atendida               39060 non-null  object
#  16  CodigoAssunto          39047 non-null  float64
#  17  DescricaoAssunto       39060 non-null  object
#  18  CodigoProblema         100 non-null    object
#  19  DescricaoProblema      89 non-null     object
#  20  SexoConsumidor         39041 non-null  object
#  21  FaixaEtariaConsumidor  39058 non-null  object
#  22  CEPConsumidor          37201 non-null  object
# dtypes: datetime64[ns](3), float64(3), int64(1), object(16)
# memory usage: 6.9+ MB

# %% [markdown]
# **Fix data type**

# %% [markdown]
# From the above, we see that the columns that have a data type problem are NumeroCNPJ, CNAEPrincipal, CodigoProblema, and CEPConsumidor. Based on the Sindec dictionary, all these columns should be numeric. However, the command above shows they are an object(string or a mix of string and numeric values).
# <br>
# The NumeroCNPJ is a column of identification in the Brazilian system it is a unique number of each company. In this analysis, we will set the Null values and alphabet character's values to 0 to avoid problems while converting them to integers. for the final column format, we are going to use a string because this an identification number.

# %%
def convert_to_numeric(x): #function to convert columns type to integer
    patterns='[a-zA-Z]'
    Maske=sindec[x].str.contains(patterns,na=False) #check the non-numeric values
    sindec[x].mask(Maske,other=None,inplace=True) #replace strings that can't be convert to a null value
    sindec[x].fillna(0,inplace=True)
    sindec[x]=sindec[x].astype('str')

# %%
fix_type=['NumeroCNPJ','CNAEPrincipal','CodigoProblema','CEPConsumidor']
for fix in fix_type:
    convert_to_numeric(fix)
sindec['DescCNAEPrincipal']=sindec['DescCNAEPrincipal'].astype('str')

# %% [markdown]
# **Cleaning Data**

# %%
null=sindec.isnull()
sns.heatmap(~null, cbar=False, yticklabels=False)

# %% [markdown]
# The graph above shows the columns where we have missing data. The black dashes represent the missing values. We see that column  DescricaProblema is empty, but this column is not necessary for our analysis because it is the user description of the problem and we can rely just on the code problem( CodigoProblema) because it standardizes using the problem code.
# Disclaimer: I check the dictionary and there is not a clear specification about the code problem I emailed SINDEC, but because of social distancing they are operating with decided people and haven't time to answer me back

# %% [markdown]
# **Fixing anomalies NumeroCNPJ**

# %% [markdown]
#  NumeroCNPJ is consisted of 14 digits starting with a 0, because of the way the dataset was made is likely that there a many values with 13 digits.so we are going to find these values and add an zero before.

# %%
print('number 13-digit values '+str((sindec[sindec['NumeroCNPJ'].str.len()==13]).shape[0]))
thirteen_digits=[sindec['NumeroCNPJ'].str.len()==13]
def thirteen_digits(x):
    if len(x)==13:
        return '0'+str(x)
    else:
        return x
sindec.NumeroCNPJ=sindec.NumeroCNPJ.map(thirteen_digits)
# Out:
# number 13-digit values 10787

# %% [markdown]
# All the NumeroCNPJ values with less than 13-digits are not useful for our analysis so we are going to set it as Null values

# %%
less_thirteen=sindec['NumeroCNPJ'].str.len()<13
sindec.NumeroCNPJ.mask(less_thirteen,other=None,inplace=True)

# %% [markdown]
# **Imputing missing values**

# %% [markdown]
# According to the Dictionary, there are 4 ways to identify a company
# strNomeFantasia(The name consumers know), NomeFantasiaRFB(according to internal Revenue Service), but there is also a number which is the id of each company. There are rows in which we don't have the strNomeFantasiaom but we have the id number to recover these names we are going to look in another column which has the same id number and copy the name.

# %%
CNPJ_NAME=sindec[(sindec['NumeroCNPJ'].notnull()) & (sindec['strNomeFantasia'].notnull())] #select no missing CNPJ and NAME
z=CNPJ_NAME.groupby('NumeroCNPJ')['strNomeFantasia'] 
z.value_counts().sort_values(ascending=False)
# Out:
# NumeroCNPJ       strNomeFantasia
# 04206050000180   TIM CELULAR                         1046
# 10979023000143   LOJASKD.COM.BR / LOJAS KD            823
# 02558157000162   VIVO/TELEFÔNICA                      752
# 61695227000193   ENEL DISTRIBUIÇÃO SÃO PAULO          722
# 40432544000147   CLARO / NET / EMBRATEL / CLAROTV     673
#                                                      ...
# 2382073000110.0  PROLAGOS                               1
# 2382985000192.0  AIRTON WOLTER ME                       1
# 23841973000159   CRISTINA BUENO IMOVEIS                 1
# 23848458000109   CENTRO EDUCACIONAL DOM QUIXOTE         1
# 01000893000138   WWW.UNIESP.EDU.BR/UNISUZ               1
# Name: strNomeFantasia, Length: 8279, dtype: int64

# %% [markdown]
# The table above shows that there are different names for the same CNPJ number, looking to the table we see that is because it refers to the different companies' departments. Our approach is to use the most common name to fill the missing values.

# %%
CNPJ=CNPJ_NAME.groupby('NumeroCNPJ')['strNomeFantasia'].agg(pd.Series.mode)#most common value for NumeroCNPJ
di=dict(CNPJ)
CNPJ_null=(sindec['strNomeFantasia'].isnull()) #the missing values we want to fix
sindec.loc[CNPJ_null,'strNomeFantasia']=sindec.loc[CNPJ_null,'NumeroCNPJ'].map(di)

# %%
sindec['strNomeFantasia'].isnull().value_counts() # reimaning missing values
# Out:
# False    34824
# True      4236
# Name: strNomeFantasia, dtype: int64

# %%
sindec['UF'].isnull().value_counts()
# Out:
# False    39060
# Name: UF, dtype: int64

# %% [markdown]
# We could not fix all the companies name(strNomeFantasia), but we opted to keep  the missing name rows values because  we  can find out which state it belongs to.

# %% [markdown]
# **Translating Key values for our analysis**

# %% [markdown]
# Dear reader, feel free to skip this part. The change you need to know is that I created a column complaint_category that is the translation of DescricaoAssunto and sector_activity which is the translation of CNAEPrincipal that describes the activity of the company.

# %% [markdown]
# To make the analysis more intuitive for non-Portuguese speakers now we are going to translate the column DescricaoAssunto which represents the sector the company works. For this part, we are using the googletrans library. We are doing a list of unique values because this library is slow and running 39k rows would demand time so instead, we only run for 209 uniques values and apply the dictionary to translate the values.

# %%
# def translate(x,y): # x is the value we want to translate and y is the translation
#     port=sindec[x].unique()
#     translate=pd.DataFrame(port,columns=['portuguese'])

#     from googletrans import Translator
#     translator = Translator()
#     translate[y]=translate['portuguese'].apply(translator.translate, src='pt', dest='en').apply(getattr, args=('text',))
#     translate_dict=pd.Series(translate[y].values,index=translate['portuguese'])
#     sindec[y]=sindec[x]
#     sindec[y]=sindec[y].map(translate_dict)

# translate('DescricaoAssunto','complaint_category')
# translate('DescCNAEPrincipal','sector_activity')

# sindec.to_csv(r'C:\\Users\\tiago\\meu procon\\sindec.csv')

# %% [markdown]
# Because this library takes too much time to run and it makes our code considerably slower we created another CSV file. and this part of the code will be in the comment format.

# %%
date_columns=['AnoCalendario','DataArquivamento','DataAbertura'] #columns to be handle in the dataformat
sindec_clean=pd.read_csv("C:\\Users\\tiago\\meu procon\\sindec.csv",parse_dates=date_columns,index_col=0)
delete=['DescricaoProblema','CodigoProblema','DescricaoAssunto','CodigoProblema','Tipo','NomeFantasiaRFB','DescCNAEPrincipal']

# %% [markdown]
# **Analysis**

# %% [markdown]
# To recap:
# in this analysis we are interesting in the questions Questions:
#     <br> Is the survey satisfaction reliable?
#     Do the questions capture the main complaints?
#     is there a difference in the results in different states? The telephone sector is also the top rank complaint in all the states? is there a correlation between non-specialized stores and complaints?

# %%
percent_state=sindec_clean['UF'].value_counts(normalize=True)*100 #filtering by states in Brazil.
fig, ax =plt.subplots(1,1,figsize=(8,5))
sns.set(font_scale=1.3)
sns.barplot(x=percent_state.index,y=percent_state).set_title("Percentage")
# Out:
# Text(0.5, 1.0, 'Percentage')

# %% [markdown]
# We noticed that São Paulo(SP) is the Brazilian state with most complaints, representing more than 60% of the whole country. However, it does not mean that the quality of services is worse in SP because it has the biggest population in brazil having more the twice the second most populated state in brazil.

# %% [markdown]
# Now we want to have a look at which companies sector has more complaints, it is just important to mention that sector_activity information comes from the Internal Revenue Service.

# %%
percent_sector=(sindec_clean['sector_activity'].value_counts(normalize=True)*100).head(30)
fig, ax =plt.subplots(1,1,figsize=(10,10))
sns.set(font_scale=1.3)
sns.barplot(x=percent_sector,y=percent_sector.index).set_title("Percentage")
# Out:
# Text(0.5, 1.0, 'Percentage')

# %% [markdown]
# One conclusion is that if we treat the whole telephonic sectors as one, what makes sense since all the companies in brazil do both services, we already can tell it is the one with most complaints being bigger than MULTIPLES BANKS WITH  COMMERCIAL PORTFOLIO. To confirm our theory we are going to analyze complaint_category, which is the required information.

# %%
percent_complaint=(sindec_clean['complaint_category'].value_counts(normalize=True)*100).head(30)
fig, ax =plt.subplots(1,1,figsize=(10,10))
sns.set(font_scale=1.3)
sns.barplot(x=percent_complaint,y=percent_complaint.index).set_title("Percentage")
# Out:
# Text(0.5, 1.0, 'Percentage')

# %% [markdown]
# Confirming our theory the Telephone services are the ones with most complaints. São Paulo is the state with most complaints in the country, so we are going to have a look in the category of these complains in the state. For the other states we are just going to have a look in the main complain.

# %%
sindec_sp=sindec_clean[sindec_clean['UF']=='SP']
percent_complaint=(sindec_sp['complaint_category'].value_counts(normalize=True)*100).head(30)
fig, ax =plt.subplots(1,1,figsize=(10,10))
sns.set(font_scale=1.3)
sns.barplot(x=percent_complaint,y=percent_complaint.index).set_title("Percentage")
# Out:
# Text(0.5, 1.0, 'Percentage')

# %%
sindec_clean.groupby(['UF']).complaint_category.agg([pd.Series.mode])
# Out:
#                                                  mode
# UF
# ES  Telephone (Conventional, Cellular, Intercom, E...
# GO  Telephone (Conventional, Cellular, Intercom, E...
# MA  Telephone (Conventional, Cellular, Intercom, E...
# MG  Fixed Telephony (Expansion Plan / Purchase and...
# MS  Telephone (Conventional, Cellular, Intercom, E...
# MT  Telephone (Conventional, Cellular, Intercom, E...
# PA                                        Electricity
# PB  Telephone (Conventional, Cellular, Intercom, E...
# RJ                                      Water / Sewer
# RN  Telephone (Conventional, Cellular, Intercom, E...
# RS                                        Electricity
# SC                                      Mobile Phones
# SP  Fixed Telephony (Expansion Plan / Purchase and...

# %% [markdown]
# The table above shows the main complaint in each state, except Pará(PA), Rio de Janeiro(RJ) and the Rio Grande do Sul(RS) the top complaint is related to the telephone sector.

# %% [markdown]
# We had an overview of different complaint activity sector, now we are going to focus only on the telephonic services. To do so we are going to use the regular expression "[p]hon" because all the related results have this way at some point

# %%
pattern="[Pp]hon"
telephone_=sindec_clean[sindec_clean['complaint_category'].str.contains(pattern)]
telephone_=telephone_[telephone_['complaint_category']!='Electronic / Battery / Electric Appliance Accessory (Needle, Earphone, Battery, etc.)']

# %%
percent_complaint=(telephone_['complaint_category'].value_counts(normalize=True)*100).head(30)
fig, ax =plt.subplots(1,1,figsize=(10,10))
sns.set(font_scale=1.3)
sns.barplot(x=percent_complaint,y=percent_complaint.index).set_title("Percentage")
# Out:
# Text(0.5, 1.0, 'Percentage')

# %% [markdown]
# Now that we already define which sector we are going to analyze,Telephonic one, we are going to make comparisons with the survey made by the National Telecommunications Agency.

# %% [markdown]
# **Data overview Anatel survey**

# %%
survey=pd.read_csv("C:\\Users\\tiago\\Downloads\\carros\\reclamacoes\\resulstado consolidado\\Relatorio_Consolidado_SCM - Tabela_Consolidada_Anatel.csv")

# %%
survey.head()
# Out:
#   SERVIÇO OPERADORA ESTADO                CALCULO QUESTÃO  \
# 0     SCM     ALGAR     MG             Percentual    B1_2
# 1     SCM     ALGAR     MG        Média Ponderada    B1_2
# 2     SCM     ALGAR     MG  Amostra não ponderada    B1_2
# 3     SCM     ALGAR     MG             Percentual    B1_2
# 4     SCM     ALGAR     MG             Percentual    B1_2
#
#                                                 TEMA             ALTERNATIVA  \
# 0  A operadora cumpre o que promete e divulga em ...  Não sabe/Não respondeu
# 1  A operadora cumpre o que promete e divulga em ...                   Média
# 2  A operadora cumpre o que promete e divulga em ...                     NaN
# 3  A operadora cumpre o que promete e divulga em ...               0.Péssimo
# 4  A operadora cumpre o que promete e divulga em ...                  Nota 1
#
#    2015  2016  2017  2018  2019
# 0  0.78  0.35  0.72  0.38  0.47
# 1  7.21  6.89  6.64  7.15  6.70
# 2   383   289   279   265   215
# 3  2.87  5.19  5.02  4.15  7.44
# 4  1.04  2.42  1.79  1.13  0.93

# %%
survey.tail()
# Out:
#       SERVIÇO     OPERADORA ESTADO     CALCULO QUESTÃO          TEMA  \
# 61023     SCM  TOTAL BRASIL  Total  Percentual      H3  Escolaridade
# 61024     SCM  TOTAL BRASIL  Total  Percentual      H3  Escolaridade
# 61025     SCM  TOTAL BRASIL  Total  Percentual      H3  Escolaridade
# 61026     SCM  TOTAL BRASIL  Total  Percentual      H3  Escolaridade
# 61027     SCM  TOTAL BRASIL  Total  Percentual      H3  Escolaridade
#
#                                              ALTERNATIVA 2015 2016 2017  \
# 61023  Ensino médio completo (inclui também curso téc...  NaN  NaN  NaN
# 61024  Ensino superior incompleto (cursando ou 3º gra...  NaN  NaN  NaN
# 61025        Ensino superior completo (3º grau completo)  NaN  NaN  NaN
# 61026  Pós-graduação incompleta (cursando ou Pós inco...  NaN  NaN  NaN
# 61027  Pós-graduação completa (inclui MBA, mestrado e...  NaN  NaN  NaN
#
#         2018   2019
# 61023  31.09  32.12
# 61024   9.64   9.20
# 61025  32.93  34.75
# 61026   0.70   0.67
# 61027   6.41   6.99

# %%
survey.ESTADO.unique()
# Out:
# array(['MG', 'SP', 'Total', 'RJ', 'RO', 'RS', 'SC', 'CE', 'PB', 'RN',
#        'AL', 'BA', 'DF', 'ES', 'GO', 'MS', 'MT', 'PE', 'PR', 'SE', 'AC',
#        'AM', 'MA', 'PA', 'PI', 'TO', 'AP', 'RR'], dtype=object)

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61028 entries, 0 to 61027
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SERVIÇO      61028 non-null  object
#  1   OPERADORA    61028 non-null  object
#  2   ESTADO       61028 non-null  object
#  3   CALCULO      61027 non-null  object
#  4   QUESTÃO      61028 non-null  object
#  5   TEMA         61028 non-null  object
#  6   ALTERNATIVA  53729 non-null  object
#  7   2015         37648 non-null  object
#  8   2016         38490 non-null  object
#  9   2017         42203 non-null  object
#  10  2018         45317 non-null  object
#  11  2019         45606 non-null  object
# dtypes: object(12)
# memory usage: 5.6+ MB

# %% [markdown]
# There is also a data problem with the year columns  2015,2016,2017,2018 and 2018 because it should be a numeric type because it represents the score of the survey.Also it is important to highlight that there is a few values that show the results for the whole country including all the companies.

# %% [markdown]
# **Fixing data type**

# %% [markdown]
# Trying to fix the data type we get a message saying "could not convert string to float: '5,589'" it happens because in brazil the decimal separator is a comma.So let's fix it and convert to the float type

# %%
survey['2018']=survey['2018'].str.replace(',','.')
survey['2018']=survey['2018'].astype('float64')

# %%
survey['ESTADO']
# Out:
# 0           MG
# 1           MG
# 2           MG
# 3           MG
# 4           MG
#          ...
# 61023    Total
# 61024    Total
# 61025    Total
# 61026    Total
# 61027    Total
# Name: ESTADO, Length: 61028, dtype: object
